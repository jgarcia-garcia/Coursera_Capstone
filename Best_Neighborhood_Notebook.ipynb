# %% [markdown]
# # Battle of Neighborhoods
#
# This notebook will be mainly used for the capstone project for the IBM Data Science Professional Certification

# %%
#Import basic libraries: Pandas and Numpy
import pandas as pd
import numpy as np

# %%
#Print the following the statement: Hello Capstone Project Course!
print('Hello Capstone Project Course!');
# Out:
# Hello Capstone Project Course!
